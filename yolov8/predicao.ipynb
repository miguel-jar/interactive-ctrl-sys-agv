# %%
from ultralytics import YOLO

obb_v1 = "modelos/obb_v1/best.pt"
obb_v2 = "modelos/obb_v2/best.pt"
obb_v3 = "modelos/obb_v3/best.pt"
obb_v4 = "modelos/obb_v4/best.pt"
obb_v5 = 'modelos/obb_v5/best.pt'

normal_v1 = "modelos/v1/best.pt"
normal_v2 = "modelos/v2/best.pt"
normal_v3 = "modelos/v3/best.pt"
normal_v4 = "modelos/v4/best.pt"

misturado = "modelos/v1_cor_com_grayscale/best.pt"
grayscale = "modelos/v1_full_grayscale/best.pt"

percurso1 = "fotos/percurso1/*.jpg"
percurso2 = "fotos/percurso2/*.jpg"
percurso3 = "fotos/percurso3/*.jpg"

percurso = percurso1

# %%
# obb_v1

model = YOLO(obb_v1)  # load a custom model
results = model.predict(percurso, imgsz=(736, 736), show=False, save=True, iou=0.4, save_txt=True, save_conf=True)  # predict on an image
# Out:
# image 1/1 c:\Users\batut\OneDrive\rea de Trabalho\tcc-yolov8\fotos\percurso3\010.jpg: 416x736 50.0ms
# Speed: 4.0ms preprocess, 50.0ms inference, 7.0ms postprocess per image at shape (1, 3, 416, 736)
# Results saved to runs\obb\predict
# 1 label saved to runs\obb\predict\labels

# %%
# obb_v1

model = YOLO(obb_v2)  # load a custom model
results = model.predict(percurso, imgsz=(736, 736), show=False, save=True, iou=0.4, save_txt=True, save_conf=True)  # predict on an image
# Out:
# image 1/11 c:\Users\batut\OneDrive\rea de Trabalho\tcc-yolov8\fotos\percurso3\000.jpg: 416x736 58.0ms
# image 2/11 c:\Users\batut\OneDrive\rea de Trabalho\tcc-yolov8\fotos\percurso3\001.jpg: 416x736 53.8ms
# image 3/11 c:\Users\batut\OneDrive\rea de Trabalho\tcc-yolov8\fotos\percurso3\002.jpg: 416x736 52.9ms
# image 4/11 c:\Users\batut\OneDrive\rea de Trabalho\tcc-yolov8\fotos\percurso3\003.jpg: 416x736 55.0ms
# image 5/11 c:\Users\batut\OneDrive\rea de Trabalho\tcc-yolov8\fotos\percurso3\004.jpg: 416x736 54.9ms
# image 6/11 c:\Users\batut\OneDrive\rea de Trabalho\tcc-yolov8\fotos\percurso3\005.jpg: 416x736 57.6ms
# image 7/11 c:\Users\batut\OneDrive\rea de Trabalho\tcc-yolov8\fotos\percurso3\006.jpg: 416x736 53.2ms
# image 8/11 c:\Users\batut\OneDrive\rea de Trabalho\tcc-yolov8\fotos\percurso3\007.jpg: 416x736 53.3ms
# image 9/11 c:\Users\batut\OneDrive\rea de Trabalho\tcc-yolov8\fotos\percurso3\008.jpg: 416x736 54.6ms
# ...

# %%
# obb_v3

model = YOLO(obb_v3)  # load a custom model
results = model.predict(percurso, imgsz=(736, 736), show=False, save=True, iou=0.4, save_txt=True, save_conf=True)  # predict on an image
# Out:
# image 1/11 c:\Users\batut\OneDrive\rea de Trabalho\tcc-yolov8\fotos\percurso3\000.jpg: 416x736 66.1ms
# image 2/11 c:\Users\batut\OneDrive\rea de Trabalho\tcc-yolov8\fotos\percurso3\001.jpg: 416x736 65.4ms
# image 3/11 c:\Users\batut\OneDrive\rea de Trabalho\tcc-yolov8\fotos\percurso3\002.jpg: 416x736 65.6ms
# image 4/11 c:\Users\batut\OneDrive\rea de Trabalho\tcc-yolov8\fotos\percurso3\003.jpg: 416x736 65.5ms
# image 5/11 c:\Users\batut\OneDrive\rea de Trabalho\tcc-yolov8\fotos\percurso3\004.jpg: 416x736 64.2ms
# image 6/11 c:\Users\batut\OneDrive\rea de Trabalho\tcc-yolov8\fotos\percurso3\005.jpg: 416x736 64.9ms
# image 7/11 c:\Users\batut\OneDrive\rea de Trabalho\tcc-yolov8\fotos\percurso3\006.jpg: 416x736 68.0ms
# image 8/11 c:\Users\batut\OneDrive\rea de Trabalho\tcc-yolov8\fotos\percurso3\007.jpg: 416x736 64.5ms
# image 9/11 c:\Users\batut\OneDrive\rea de Trabalho\tcc-yolov8\fotos\percurso3\008.jpg: 416x736 64.6ms
# ...

# %%
# obb_v4

model = YOLO(obb_v4)  # load a custom model
results = model.predict(percurso, imgsz=(736, 736), show=False, save=True, iou=0.4, save_txt=True, save_conf=True)  # predict on an image
# Out:
# image 1/11 c:\Users\batut\OneDrive\rea de Trabalho\tcc-yolov8\fotos\percurso3\000.jpg: 384x640 57.0ms
# image 2/11 c:\Users\batut\OneDrive\rea de Trabalho\tcc-yolov8\fotos\percurso3\001.jpg: 384x640 52.0ms
# image 3/11 c:\Users\batut\OneDrive\rea de Trabalho\tcc-yolov8\fotos\percurso3\002.jpg: 384x640 52.0ms
# image 4/11 c:\Users\batut\OneDrive\rea de Trabalho\tcc-yolov8\fotos\percurso3\003.jpg: 384x640 52.0ms
# image 5/11 c:\Users\batut\OneDrive\rea de Trabalho\tcc-yolov8\fotos\percurso3\004.jpg: 384x640 54.0ms
# image 6/11 c:\Users\batut\OneDrive\rea de Trabalho\tcc-yolov8\fotos\percurso3\005.jpg: 384x640 53.0ms
# image 7/11 c:\Users\batut\OneDrive\rea de Trabalho\tcc-yolov8\fotos\percurso3\006.jpg: 384x640 51.0ms
# image 8/11 c:\Users\batut\OneDrive\rea de Trabalho\tcc-yolov8\fotos\percurso3\007.jpg: 384x640 52.0ms
# image 9/11 c:\Users\batut\OneDrive\rea de Trabalho\tcc-yolov8\fotos\percurso3\008.jpg: 384x640 52.0ms
# ...

# %%
# v4

model = YOLO(normal_v4)  # load a custom model
results = model.predict(percurso, imgsz=(736, 736), show=False, save=True, iou=0.4, save_txt=True, save_conf=True)  # predict on an image
# Out:
# image 1/11 c:\Users\batut\OneDrive\rea de Trabalho\tcc-yolov8\fotos\percurso3\000.jpg: 288x480 1 cars, 1 path, 33.3ms
# image 2/11 c:\Users\batut\OneDrive\rea de Trabalho\tcc-yolov8\fotos\percurso3\001.jpg: 288x480 1 cars, 1 path, 34.3ms
# image 3/11 c:\Users\batut\OneDrive\rea de Trabalho\tcc-yolov8\fotos\percurso3\002.jpg: 288x480 1 cars, 1 path, 36.9ms
# image 4/11 c:\Users\batut\OneDrive\rea de Trabalho\tcc-yolov8\fotos\percurso3\003.jpg: 288x480 1 cars, 1 path, 34.0ms
# image 5/11 c:\Users\batut\OneDrive\rea de Trabalho\tcc-yolov8\fotos\percurso3\004.jpg: 288x480 1 cars, 1 path, 33.3ms
# image 6/11 c:\Users\batut\OneDrive\rea de Trabalho\tcc-yolov8\fotos\percurso3\005.jpg: 288x480 1 path, 32.1ms
# image 7/11 c:\Users\batut\OneDrive\rea de Trabalho\tcc-yolov8\fotos\percurso3\006.jpg: 288x480 1 cars, 1 path, 32.0ms
# image 8/11 c:\Users\batut\OneDrive\rea de Trabalho\tcc-yolov8\fotos\percurso3\007.jpg: 288x480 1 cars, 1 path, 33.0ms
# ...

# %%
# v3

model = YOLO(normal_v3)  # load a custom model
results = model.predict(percurso, imgsz=(736, 736), show=False, save=True, iou=0.4, save_txt=True, save_conf=True)  # predict on an image
# Out:
# image 1/7 c:\Users\batut\OneDrive\rea de Trabalho\tcc-yolov8\fotos\percurso1\0.jpg: 416x736 1 cars, 57.4ms
# image 2/7 c:\Users\batut\OneDrive\rea de Trabalho\tcc-yolov8\fotos\percurso1\1.jpg: 416x736 1 cars, 1 path, 62.4ms
# image 3/7 c:\Users\batut\OneDrive\rea de Trabalho\tcc-yolov8\fotos\percurso1\2.jpg: 416x736 1 cars, 53.0ms
# image 4/7 c:\Users\batut\OneDrive\rea de Trabalho\tcc-yolov8\fotos\percurso1\3.jpg: 416x736 1 cars, 55.0ms
# image 5/7 c:\Users\batut\OneDrive\rea de Trabalho\tcc-yolov8\fotos\percurso1\4.jpg: 416x736 1 cars, 53.0ms
# image 6/7 c:\Users\batut\OneDrive\rea de Trabalho\tcc-yolov8\fotos\percurso1\5.jpg: 416x736 1 cars, 54.0ms
# image 7/7 c:\Users\batut\OneDrive\rea de Trabalho\tcc-yolov8\fotos\percurso1\6.jpg: 416x736 1 cars, 54.0ms
# Speed: 6.0ms preprocess, 55.5ms inference, 23.4ms postprocess per image at shape (1, 3, 416, 736)
# Results saved to runs\detect\predict
# 7 labels saved to runs\detect\predict\labels

# %%
# v2

model = YOLO(normal_v2)  # load a custom model
results = model.predict(percurso, imgsz=(736, 736), show=False, save=True, iou=0.4, save_txt=True, save_conf=True)  # predict on an image
# Out:
# image 1/7 c:\Users\batut\OneDrive\rea de Trabalho\tcc-yolov8\fotos\percurso1\0.jpg: 416x736 1 cars, 1 path, 49.0ms
# image 2/7 c:\Users\batut\OneDrive\rea de Trabalho\tcc-yolov8\fotos\percurso1\1.jpg: 416x736 1 cars, 2 paths, 48.0ms
# image 3/7 c:\Users\batut\OneDrive\rea de Trabalho\tcc-yolov8\fotos\percurso1\2.jpg: 416x736 1 cars, 2 paths, 48.0ms
# image 4/7 c:\Users\batut\OneDrive\rea de Trabalho\tcc-yolov8\fotos\percurso1\3.jpg: 416x736 1 cars, 2 paths, 48.0ms
# image 5/7 c:\Users\batut\OneDrive\rea de Trabalho\tcc-yolov8\fotos\percurso1\4.jpg: 416x736 1 cars, 1 path, 48.0ms
# image 6/7 c:\Users\batut\OneDrive\rea de Trabalho\tcc-yolov8\fotos\percurso1\5.jpg: 416x736 1 cars, 2 paths, 47.0ms
# image 7/7 c:\Users\batut\OneDrive\rea de Trabalho\tcc-yolov8\fotos\percurso1\6.jpg: 416x736 2 carss, 2 paths, 47.0ms
# Speed: 3.6ms preprocess, 47.8ms inference, 2.7ms postprocess per image at shape (1, 3, 416, 736)
# Results saved to runs\detect\predict3
# ...

# %%
# v1

model = YOLO(normal_v1)  # load a custom model
results = model.predict(percurso, imgsz=(736, 736), show=False, save=True, iou=0.4, save_txt=True, save_conf=True)  # predict on an image

# %%
# misturado

model = YOLO(grayscale)  # load a custom model
results = model.predict(percurso, imgsz=(736, 736), show=False, save=True, iou=0.4, save_txt=True, save_conf=True)  # predict on an image
# Out:
# image 1/7 c:\Users\batut\OneDrive\rea de Trabalho\tcc-yolov8\fotos\percurso1\0.jpg: 416x736 1 path, 61.0ms
# image 2/7 c:\Users\batut\OneDrive\rea de Trabalho\tcc-yolov8\fotos\percurso1\1.jpg: 416x736 1 cars, 2 paths, 52.0ms
# image 3/7 c:\Users\batut\OneDrive\rea de Trabalho\tcc-yolov8\fotos\percurso1\2.jpg: 416x736 1 cars, 2 paths, 52.0ms
# image 4/7 c:\Users\batut\OneDrive\rea de Trabalho\tcc-yolov8\fotos\percurso1\3.jpg: 416x736 2 paths, 54.0ms
# image 5/7 c:\Users\batut\OneDrive\rea de Trabalho\tcc-yolov8\fotos\percurso1\4.jpg: 416x736 1 path, 51.8ms
# image 6/7 c:\Users\batut\OneDrive\rea de Trabalho\tcc-yolov8\fotos\percurso1\5.jpg: 416x736 1 path, 53.0ms
# image 7/7 c:\Users\batut\OneDrive\rea de Trabalho\tcc-yolov8\fotos\percurso1\6.jpg: 416x736 (no detections), 51.0ms
# Speed: 5.9ms preprocess, 53.5ms inference, 4.1ms postprocess per image at shape (1, 3, 416, 736)
# Results saved to runs\detect\predict2
# 6 labels saved to runs\detect\predict2\labels
